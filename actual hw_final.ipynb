# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install dm-haiku
# !pip install pretty_midi
# !pip install optax
# !pip install basic_pitch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dm-haiku in /usr/local/lib/python3.8/dist-packages (0.0.9)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from dm-haiku) (1.21.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.8/dist-packages (from dm-haiku) (0.8.10)
# Requirement already satisfied: jmp>=0.0.2 in /usr/local/lib/python3.8/dist-packages (from dm-haiku) (0.0.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from dm-haiku) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 5.4 MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from pretty_midi) (1.21.6)
# Collecting mido>=1.1.16
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 7.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from pretty_midi) (1.15.0)
# Building wheels for collected packages: pretty-midi
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591954 sha256=0f0c1097f95cfce63465c81536c74c7896b90bb6ee2922554d8dbd1b601bb22a
#   Stored in directory: /root/.cache/pip/wheels/2a/5a/e3/30eeb9a99350f3f7e21258fcb132743eef1a4f49b3505e76b6
# Successfully built pretty-midi
# Installing collected packages: mido, pretty-midi
# Successfully installed mido-1.2.10 pretty-midi-0.2.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optax
#   Downloading optax-0.1.4-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 8.2 MB/s
# Collecting chex>=0.1.5
#   Downloading chex-0.1.5-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.8 MB/s
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from optax) (1.3.0)
# Requirement already satisfied: jax>=0.1.55 in /usr/local/lib/python3.8/dist-packages (from optax) (0.3.25)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from optax) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.8/dist-packages (from optax) (4.4.0)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.8/dist-packages (from optax) (0.3.25+cuda11.cudnn805)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.8/dist-packages (from chex>=0.1.5->optax) (0.1.7)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from chex>=0.1.5->optax) (0.12.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.8/dist-packages (from jax>=0.1.55->optax) (1.7.3)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.8/dist-packages (from jax>=0.1.55->optax) (3.3.0)
# Installing collected packages: chex, optax
# Successfully installed chex-0.1.5 optax-0.1.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basic_pitch
#   Downloading basic-pitch-0.2.0.tar.gz (2.0 MB)
#      |████████████████████████████████| 2.0 MB 7.4 MB/s
# Requirement already satisfied: librosa>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from basic_pitch) (0.8.1)
# Collecting mir_eval>=0.6
#   Downloading mir_eval-0.7.tar.gz (90 kB)
#      |████████████████████████████████| 90 kB 10.7 MB/s
# Requirement already satisfied: pretty_midi>=0.2.9 in /usr/local/lib/python3.8/dist-packages (from basic_pitch) (0.2.9)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from basic_pitch) (0.4.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from basic_pitch) (1.7.3)
# Requirement already satisfied: tensorflow<2.10,>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from basic_pitch) (2.9.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.8/dist-packages (from basic_pitch) (4.4.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (1.6.0)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (0.56.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (21.3)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (1.2.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (0.11.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (1.21.6)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (4.4.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->basic_pitch) (1.0.2)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from mir_eval>=0.6->basic_pitch) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from mir_eval>=0.6->basic_pitch) (1.15.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa>=0.8.0->basic_pitch) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa>=0.8.0->basic_pitch) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa>=0.8.0->basic_pitch) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->librosa>=0.8.0->basic_pitch) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa>=0.8.0->basic_pitch) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa>=0.8.0->basic_pitch) (2.23.0)
# Requirement already satisfied: mido>=1.1.16 in /usr/local/lib/python3.8/dist-packages (from pretty_midi>=0.2.9->basic_pitch) (1.2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->basic_pitch) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->basic_pitch) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->basic_pitch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->basic_pitch) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa>=0.8.0->basic_pitch) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile>=0.10.2->librosa>=0.8.0->basic_pitch) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa>=0.8.0->basic_pitch) (2.21)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (14.0.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (1.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (2.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (1.51.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (0.4.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (2.9.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (1.1.2)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (2.1.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (1.12)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (0.28.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.10,>=2.4.1->basic_pitch) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow<2.10,>=2.4.1->basic_pitch) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (2.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (1.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.43.0->librosa>=0.8.0->basic_pitch) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.4.1->basic_pitch) (3.2.2)
# Building wheels for collected packages: basic-pitch, mir-eval
#   Building wheel for basic-pitch (setup.py) ... done
#   Created wheel for basic-pitch: filename=basic_pitch-0.2.0-py2.py3-none-any.whl size=373298 sha256=aed1428ceac03604268d950d0850c43066666a88255ced1aeb7b854e50e6449e
#   Stored in directory: /root/.cache/pip/wheels/75/5b/6d/afbf6bdb67e2c3dcac1ce92322181ab1c40e8953f4d1d500c6
#   Building wheel for mir-eval (setup.py) ... done
#   Created wheel for mir-eval: filename=mir_eval-0.7-py3-none-any.whl size=100720 sha256=6a0b032e2a562e59d844909c5cf42da6b1d568e06628bd33350d7be807af5d22
#   Stored in directory: /root/.cache/pip/wheels/20/53/83/1d50d15a666140d53eda589db005f7cb53b739c7e54711f51f
# Successfully built basic-pitch mir-eval
# Installing collected packages: mir-eval, basic-pitch
# Successfully installed basic-pitch-0.2.0 mir-eval-0.7

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from typing import Union, List, Dict, Tuple

import numpy as np
# import tensorflow as tf
import random

import jax
from jax import value_and_grad
import jax.numpy as jnp
import optax
import haiku as hk

import librosa
import pathlib
from tqdm import tqdm

import matplotlib.pyplot as plt
from pretty_midi import PrettyMIDI

from IPython.display import display, Audio

import sys
import os
FOLDER_PATH = "/content/drive/MyDrive/badpitches/v3"
sys.path.insert(0, FOLDER_PATH)

from loss import loss_dict
from constants import *
from new_model_in_jax import PosteriorgramModel
from cqt_and_hs import load_cqt_window, harmonic_stacking, load_and_cqt, cqt_windowed
from note_creation import model_output_to_notes, sonify_midi

# %% [markdown]
# # Training Attempt
# Maybe consider adding a requirements.txt

# %%
rng = jax.random.PRNGKey(0)
audio_path = "drive/MyDrive/badpitches/v3/test.m4a"
audio_tensor = load_and_cqt(audio_path)
noisy_audio = audio_tensor + jax.random.normal(rng, audio_tensor.shape)

epochs = 1000
learning_rate = 0.01
optimizer = optax.adam(learning_rate)


def update_weights(weights,gradients):
    return optimizer.update(gradients, weights)

def loss_wrapper(params, state, x, y):
    out, new_state = model.apply(params, state, rng=rng, audio_tensor=x, is_training=True)
    loss_fns = loss_dict()
    print([(w, y[w].shape) for w in y], [o.shape for o in out])
    loss_yp = jnp.sum(loss_fns["contour"](y["contour"], out[0]))
    loss_yn = jnp.sum(loss_fns["note"](y["note"], out[1]))
    loss_yo = jnp.sum(loss_fns["onset"](y["onset"], out[2]))
    loss = loss_yp + loss_yn + loss_yo
    return loss, (loss, new_state)

def step(params, opt_state, state, x, y):
    # loss_value, grads = jax.value_and_grad(loss)(params, batch, labels)
    grads, (loss, state) = jax.grad(loss_wrapper, has_aux=True)(params, state, x, y)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, state, loss

def model_fn(audio_tensor, is_training):
    bn = hk.BatchNorm(create_scale=True, create_offset=True, decay_rate=0.9, name="bn")
    normed = bn(audio_tensor, is_training)
    hs = harmonic_stacking(normed)
    pgram = PosteriorgramModel()(hs, is_training)
    
    return pgram
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# audio_array:  (113367,)
# cqt:  (84, 222)
# reshaped cqt:  (1, 84, 222)

# %%
def audio_info(path, window_len=ANNOT_N_FRAMES, window_num=0):
  """
  Returns the onset, contour, and note matrices as a dictionary for the appropriate
  window of the MIDI file located at the given path.
  """

  midi_fps = ANNOTATIONS_FPS

  pm = PrettyMIDI(path)

  start_frame = window_num * window_len
  end_frame = (window_num + 1) * window_len
  note_matrix = pm.get_piano_roll(fs=midi_fps)[21:109, start_frame:end_frame] / 127 #21 to 109 is piano bins

  onsets = np.array(pm.get_onsets() * midi_fps)
  logical_indices = np.logical_and(start_frame < onsets, onsets < end_frame)
  windowed_onsets = np.floor(onsets[logical_indices] - start_frame)

  onset_matrix = np.zeros_like(note_matrix, dtype=bool)
  
  for frame in windowed_onsets.astype(int):
    vec = note_matrix[: , frame]
    prev_vec = note_matrix[: , max(0, frame - 1)]
    onset_notes = np.argwhere(vec - prev_vec).ravel()
    for note in onset_notes:
      onset_matrix[note][frame] = True

  contour_array = [(row if i == 1 else np.zeros(row.shape)) for i in range(3) for row in note_matrix]

  return {
    "onset": jnp.array(onset_matrix),
    "contour": jnp.array(contour_array),
    "note": jnp.array(note_matrix)
  }

# %%
data_path = "/content/drive/MyDrive/badpitches_data/test_new/"
val_files = os.listdir(data_path)
files = [va.split(".")[0] for va in val_files if va.split(".")[-1] == 'midi']

# %% [markdown]
# ### Training loop

# %%
BATCH_SIZE = 1 #unbatched until batch works

batched_inputs = np.zeros((BATCH_SIZE, 84, 87, 1))
batched_outputs = {
    'note': np.zeros((BATCH_SIZE, N_FREQ_BINS_NOTES, ANNOT_N_FRAMES)),
    'contour': np.zeros((BATCH_SIZE, N_FREQ_BINS_CONTOURS, ANNOT_N_FRAMES)),
    'onset': np.zeros((BATCH_SIZE, N_FREQ_BINS_NOTES, ANNOT_N_FRAMES))
}

model = hk.transform_with_state(model_fn)
for i in tqdm(range(BATCH_SIZE)):
      rand_file_name = files[random.randint(0, len(files) - 1)]
      midi_file = data_path + rand_file_name + ".midi"
      wav_file = data_path + rand_file_name + ".wav"
      audio, window_num = load_cqt_window(wav_file)
      batched_inputs[i,:,:,:] = audio
print(batched_inputs.shape)
params, state = model.init(rng, batched_inputs, True) # pass in augmented data here to train
opt_state = optimizer.init(params)
NUM_EPOCHS = 5
for _ in tqdm(range(1, NUM_EPOCHS+1)):
    
    for i in range(BATCH_SIZE):
        rand_file_name = files[random.randint(0, len(files) - 1)]
        midi_file = data_path + rand_file_name + ".midi"
        wav_file = data_path + rand_file_name + ".wav"
        audio, window_num = load_cqt_window(wav_file)
        matrices = audio_info(midi_file, window_num=window_num)
        batched_inputs[i,:,:,:] = audio
        batched_outputs['note'][i,:,:] = matrices['note']
        batched_outputs['contour'][i,:,:] = matrices['contour']
        batched_outputs['onset'][i,:,:] = matrices['onset']
    print('note', matrices['note'].shape)
    print('cont', matrices['contour'].shape)
    print('ons', matrices['onset'].shape)
    print(batched_outputs['note'].shape)
    params, opt_state, state, loss = step(params, opt_state, state, batched_inputs, batched_outputs)
    print(loss)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# audio_array:  (44100,)
# cqt:  (84, 87)
# reshaped cqt:  (1, 84, 87)
# (1, 84, 87, 1)
# /usr/local/lib/python3.8/dist-packages/haiku/_src/base.py:515: UserWarning: Explicitly requested dtype float64 requested in ones is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   param = init(shape, dtype)
# /usr/local/lib/python3.8/dist-packages/haiku/_src/base.py:515: UserWarning: Explicitly requested dtype float64 requested in zeros is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   param = init(shape, dtype)
# (1, 84, 264, 1)
# (1, 84, 264, 16)
# (1, 84, 264, 8)
# (1, 84, 264, 1)
#   0%|          | 0/5 [00:00<?, ?it/s]
# audio_array:  (44100,)
# cqt:  (84, 87)
# reshaped cqt:  (1, 84, 87)
# note (88, 172)
# cont (264, 172)
# ons (88, 172)
# (1, 88, 172)
# (1, 84, 264, 1)
# (1, 84, 264, 16)
# (1, 84, 264, 8)
# (1, 84, 264, 1)
# [('note', (1, 88, 172)), ('contour', (1, 264, 172)), ('onset', (1, 88, 172))] [(1, 84, 264, 1), (1, 84, 88, 1), (1, 84, 88, 1)]
#  20%|██        | 1/5 [00:12<00:49, 12.28s/it]
# 6258465.5
# audio_array:  (44100,)
# cqt:  (84, 87)
# reshaped cqt:  (1, 84, 87)
# note (88, 172)
# cont (264, 172)
# ons (88, 172)
# (1, 88, 172)
# (1, 84, 264, 1)
# (1, 84, 264, 16)
# (1, 84, 264, 8)
# (1, 84, 264, 1)
# [('note', (1, 88, 172)), ('contour', (1, 264, 172)), ('onset', (1, 88, 172))] [(1, 84, 264, 1), (1, 84, 88, 1), (1, 84, 88, 1)]
#  40%|████      | 2/5 [00:16<00:22,  7.34s/it]
# 5762605.0
# audio_array:  (44100,)
# cqt:  (84, 87)
# reshaped cqt:  (1, 84, 87)
# note (88, 172)
# cont (264, 172)
# ons (88, 172)
# (1, 88, 172)
# (1, 84, 264, 1)
# (1, 84, 264, 16)
# (1, 84, 264, 8)
# (1, 84, 264, 1)
# [('note', (1, 88, 172)), ('contour', (1, 264, 172)), ('onset', (1, 88, 172))] [(1, 84, 264, 1), (1, 84, 88, 1), (1, 84, 88, 1)]
#  60%|██████    | 3/5 [00:19<00:10,  5.36s/it]
# 5424894.0
# audio_array:  (44100,)
# cqt:  (84, 87)
# reshaped cqt:  (1, 84, 87)
# note (88, 172)
# cont (264, 172)
# ons (88, 172)
# (1, 88, 172)
# (1, 84, 264, 1)
# (1, 84, 264, 16)
# (1, 84, 264, 8)
# (1, 84, 264, 1)
# [('note', (1, 88, 172)), ('contour', (1, 264, 172)), ('onset', (1, 88, 172))] [(1, 84, 264, 1), (1, 84, 88, 1), (1, 84, 88, 1)]
#  80%|████████  | 4/5 [00:23<00:04,  4.92s/it]
# 5280781.0
# audio_array:  (44100,)
# cqt:  (84, 87)
# reshaped cqt:  (1, 84, 87)
# note (88, 172)
# cont (264, 172)
# ons (88, 172)
# (1, 88, 172)
# (1, 84, 264, 1)
# (1, 84, 264, 16)
# (1, 84, 264, 8)
# (1, 84, 264, 1)
# [('note', (1, 88, 172)), ('contour', (1, 264, 172)), ('onset', (1, 88, 172))] [(1, 84, 264, 1), (1, 84, 88, 1), (1, 84, 88, 1)]
# 100%|██████████| 5/5 [00:27<00:00,  5.47s/it]
# 5315520.5

# %% [markdown]
# ## Visualize / audiate predictions
# Here we will choose a sample and see the spectrogram for the sample's expected output compared to our model's, and be able to hear them as well!
#
# The plot is the actual notes of the MIDI (digitized sheet music) file, including duration and pitch.
#
# <!-- The middle plot illustrates the "contours," or nuances of notes (because we're only working with a piano dataset here, there is little new information to be found). The last plot describes "onsets" of notes, or when notes are first played.  -->

# %%
sample_index = 12 # Change as you desire! This reflects the audio file in the corresponding folder
duration = 30 # Number of seconds to generate

# %% [markdown]
# ### Raw audio, expected audio and MIDI

# %%
assert 0 <= sample_index < len(files)
sample_name = files[sample_index]

midi_file = data_path + sample_name + ".midi"
wav_file = data_path + sample_name + ".wav"

plt.figure(figsize=(15,7))
mats = audio_info(midi_file, window_num=0, window_len=ANNOTATIONS_FPS * duration)

plt.matshow(mats["note"], fignum=1, aspect='auto', origin='lower')
_ = plt.axis('off')

raw_audio, _ = librosa.load(wav_file, duration=duration)
raw = Audio(raw_audio, rate=22050)

pm = PrettyMIDI(midi_file)
expected_audio = pm.synthesize(fs=22050)[:22050 * duration]
expected = Audio(expected_audio, rate=22050)

print("raw audio\nexpected audio")
display(raw, expected)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Predicted audio and MIDI

# %%
preprocessed_input = cqt_windowed(raw_audio)
output = model.apply(params, state, rng, preprocessed_input, is_training=False)
np_mats = {
    'note': np.asarray(output[1]).T,
    'onset': np.asarray(output[2]).T,
    'contour': np.asarray(output[0]).T
}

plt.matshow(np_mats['note'], fignum=1, aspect='auto', origin='lower')
_ = plt.axis('off')

pm_predicted, _ = model_output_to_notes(np_mats, 0.5, 0.3, include_pitch_bends=False, min_note_len=0.0, melodia_trick=False)

predicted_audio = pm_predicted.synthesize(fs=22050)[:22050 * duration]
predicted = Audio(predicted_audio, rate=22050)
display(predicted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-7a4650f375e0> in <module>
#       1 preprocessed_input = cqt_windowed(raw_audio)
# ----> 2 output = model.apply(params, state, rng, preprocessed_input, is_training=False)
#       3 np_mats = {
#       4     'note': np.asarray(output[1]).T,
#       5     'onset': np.asarray(output[2]).T,
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/transform.py in apply_fn(params, state, rng, *args, **kwargs)
#     355     with base.new_context(params=params, state=state, rng=rng) as ctx:
#     356       try:
# --> 357         out = f(*args, **kwargs)
#     358       except jax.errors.UnexpectedTracerError as e:
#     359         raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#
# <ipython-input-9-ed3dfecd5049> in model_fn(audio_tensor, is_training)
#      33     normed = bn(audio_tensor, is_training)
#      34     hs = harmonic_stacking(normed)
# ---> 35     pgram = PosteriorgramModel()(hs, is_training)
#      36
#      37     return pgram
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     424           f = jax.named_call(f, name=method_name)
#     425
# --> 426       out = f(*args, **kwargs)
#     427
#     428       # Module names are set in the constructor. If `f` is the constructor then
#
# /usr/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, *args, **kwargs)
#     270   """Runs any method interceptors or the original method."""
#     271   if not interceptor_stack:
# --> 272     return bound_method(*args, **kwargs)
#     273
#     274   ctx = MethodContext(module=self,
#
# /content/drive/MyDrive/badpitches/v3/new_model_in_jax.py in __call__(self, audio, is_training)
#     124     def __call__(self, audio: jnp.ndarray, is_training: bool) -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray]:
#     125         processed = self.cqt_harmonic_stacking(audio)
# --> 126         yp = self.yp_branch(processed, is_training)
#     127         yn = self.yn_branch(yp)
#     128         top = self.top_branch(processed, is_training)
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     424           f = jax.named_call(f, name=method_name)
#     425
# --> 426       out = f(*args, **kwargs)
#     427
#     428       # Module names are set in the constructor. If `f` is the constructor then
#
# /usr/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, *args, **kwargs)
#     270   """Runs any method interceptors or the original method."""
#     271   if not interceptor_stack:
# --> 272     return bound_method(*args, **kwargs)
#     273
#     274   ctx = MethodContext(module=self,
#
# /content/drive/MyDrive/badpitches/v3/new_model_in_jax.py in __call__(self, x, is_training)
#      52     def __call__(self, x: jnp.ndarray, is_training: bool) -> jnp.ndarray:
#      53         # x = x.transpose(0, 3, 1, 2)
# ---> 54         x = self.conv16_5_5(x)
#      55         x = self.bn1(x, is_training=is_training)
#      56         # print("after conv", x.shape)
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     424           f = jax.named_call(f, name=method_name)
#     425
# --> 426       out = f(*args, **kwargs)
#     427
#     428       # Module names are set in the constructor. If `f` is the constructor then
#
# /usr/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, *args, **kwargs)
#     270   """Runs any method interceptors or the original method."""
#     271   if not interceptor_stack:
# --> 272     return bound_method(*args, **kwargs)
#     273
#     274   ctx = MethodContext(module=self,
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/conv.py in __call__(self, inputs, precision)
#     198       stddev = 1. / np.sqrt(fan_in_shape)
#     199       w_init = hk.initializers.TruncatedNormal(stddev=stddev)
# --> 200     w = hk.get_parameter("w", w_shape, inputs.dtype, init=w_init)
#     201
#     202     if self.mask is not None:
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/base.py in wrapped(*args, **kwargs)
#     446   @functools.wraps(f)
#     447   def wrapped(*args, **kwargs):
# --> 448     return wrapped._current(*args, **kwargs)
#     449
#     450   def replace(g):
#
# /usr/local/lib/python3.8/dist-packages/haiku/_src/base.py in get_parameter(name, shape, dtype, init)
#     538
#     539   if param.shape != tuple(shape):
# --> 540     raise ValueError(
#     541         f"{fq_name!r} with retrieved shape {param.shape!r} does not match "
#     542         f"shape={shape!r} dtype={dtype!r}")
#
# ValueError: 'posteriorgram_model/~/yp_branch/~/conv16_5_5/w' with retrieved shape (5, 5, 1, 16) does not match shape=(5, 5, 8, 16) dtype=dtype('float32')
